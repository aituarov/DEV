# %%
# Downloading dataset and have a look at them.
import pandas as pd
pd.set_option('display.max_rows', 100)
data = pd.read_excel('question_1_data.xlsx')
data
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0            1       53      746           224            2           cash
# 1            2       92      925            90            1           cash
# 2            3       44      861           144            1           cash
# 3            4       18      935           156            1    credit_card
# 4            5       18      883           156            1    credit_card
# ...        ...      ...      ...           ...          ...            ...
# 4995      4996       73      993           330            2          debit
# 4996      4997       48      789           234            2           cash
# 4997      4998       56      867           351            3           cash
# 4998      4999       60      825           354            2    credit_card
# 4999      5000       44      734           288            2          debit
#
#                   created_at
# 0    2017-03-13 12:36:56.190
# ...

# %%
# I check the AOV value
total = data['order_amount'].sum()
AOV = total / data['order_id'].count()
AOV
# Out:
# 3145.128

# %%
# By summarising order_amount group by shop_id, we can see that shops with shop_id = 42 and shop_id=78 
# have huge value in order_amount
data.groupby(['shop_id'])['order_amount'].sum().sort_values(ascending=False)
# Out:
# shop_id
# 42     11990176
# 78      2263800
# 89        23128
# 81        22656
# 6         22627
# 13        21760
# 59        21538
# 71        21320
# 19        20538
# 70        20241
# 84        20196
# 90        19758
# 73        19470
# 43        19367
# 29        19234
# 12        18693
# 99        18330
# 27        18083
# 65        17864
# 88        17776
# 50        17756
# 79        17738
# 24        17640
# 10        17612
# 91        17600
# 17        17600
# 11        17480
# 23        17472
# 18        17472
# 61        17222
# 35        17056
# 96        16830
# 26        16720
# 51        16643
# 66        16583
# 30        16524
# 60        16461
# 37        16330
# 15        16065
# 69        15851
# 55        15732
# 57        15729
# 45        15620
# 97        15552
# 63        15368
# 87        15198
# 33        15051
# 58        15042
# 41        14986
# 46        14940
# 49        14835
# 82        14691
# 3         14652
# 53        14560
# 86        14430
# ...

# %%
# If we inspect orders with shop_id = 42 and shop_id = 78, we can see abnormal huge order_amount orders
print(data.loc[((data['shop_id'] == 42) | (data['shop_id'] == 78)), :].sort_values(by='order_amount', ascending=False))
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 15          16       42      607        704000         2000    credit_card
# 4646      4647       42      607        704000         2000    credit_card
# 2835      2836       42      607        704000         2000    credit_card
# 2297      2298       42      607        704000         2000    credit_card
# 2969      2970       42      607        704000         2000    credit_card
# 2153      2154       42      607        704000         2000    credit_card
# 3332      3333       42      607        704000         2000    credit_card
# 1602      1603       42      607        704000         2000    credit_card
# 1562      1563       42      607        704000         2000    credit_card
# 4056      4057       42      607        704000         2000    credit_card
# 1362      1363       42      607        704000         2000    credit_card
# ...

# %%
# Calculate one pair sneakers price for each shop
df2 = data.groupby(['shop_id'])['order_amount', 'total_items'].sum()
df2['sneaker_price'] = df2['order_amount'] / df2['total_items']
print(df2.sort_values(by='sneaker_price', ascending=False))
# Out:
#          order_amount  total_items  sneaker_price
# shop_id
# 78            2263800           88        25725.0
# 42           11990176        34063          352.0
# 12              18693           93          201.0
# 89              23128          118          196.0
# 99              18330           94          195.0
# 50              17756           92          193.0
# 38              13680           72          190.0
# 51              16643           89          187.0
# 6               22627          121          187.0
# 11              17480           95          184.0
# 79              17738           98          181.0
# 43              19367          107          181.0
# 90              19758          111          178.0
# 59              21538          121          178.0
# 60              16461           93          177.0
# 82              14691           83          177.0
# 81              22656          128          177.0
# 17              17600          100          176.0
# ...

# %%
new_data = data.loc[(data['total_items'] < 10) & (data['order_amount'] / data['total_items'] < 400), :]
print(new_data)

AOV_new = new_data['order_amount'].sum() / new_data['order_id'].count()
print('AOV: ' + str(AOV_new))
# Out:
#       order_id  shop_id  user_id  order_amount  total_items payment_method  \
# 0            1       53      746           224            2           cash
# 1            2       92      925            90            1           cash
# 2            3       44      861           144            1           cash
# 3            4       18      935           156            1    credit_card
# 4            5       18      883           156            1    credit_card
# ...        ...      ...      ...           ...          ...            ...
# 4995      4996       73      993           330            2          debit
# 4996      4997       48      789           234            2           cash
# 4997      4998       56      867           351            3           cash
# 4998      4999       60      825           354            2    credit_card
# 4999      5000       44      734           288            2          debit
#
#                   created_at
# 0    2017-03-13 12:36:56.190
# ...
